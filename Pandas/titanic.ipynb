# %%
import pandas as pd  # Import pandas for data manipulation

# Read the Titanic dataset from a CSV file into a pandas DataFrame
df = pd.read_csv("../Datasets/titanic.csv")

# Display the DataFrame (first and last 5 rows by default)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
# Select rows where the passenger did not survive (Survived == 0) and is male (Sex == 'male')
df[(df['Survived'] == 0) & (df['Sex'] == 'male')]
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 0            892         0       3              Kelly, Mr. James  male  34.5
# 2            894         0       2     Myles, Mr. Thomas Francis  male  62.0
# 3            895         0       3              Wirz, Mr. Albert  male  27.0
# 5            897         0       3    Svensson, Mr. Johan Cervin  male  14.0
# 7            899         0       2  Caldwell, Mr. Albert Francis  male  26.0
# ..           ...       ...     ...                           ...   ...   ...
# 407         1299         0       1    Widener, Mr. George Dunton  male  50.0
# 413         1305         0       3            Spector, Mr. Woolf  male   NaN
# 415         1307         0       3  Saether, Mr. Simon Sivertsen  male  38.5
# 416         1308         0       3           Ware, Mr. Frederick  male   NaN
# 417         1309         0       3      Peter, Master. Michael J  male   NaN
#
# ...

# %%
# Select rows where the 'Age' value is missing (NaN)
df[df['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 10           902         0       3
# 22           914         1       1
# 29           921         0       3
# 33           925         1       3
# 36           928         1       3
# ..           ...       ...     ...
# 408         1300         1       3
# 410         1302         1       3
# 413         1305         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 10                                    Ilieff, Mr. Ylio    male  NaN      0
# 22                Flegenheim, Mrs. Alfred (Antoinette)  female  NaN      0
# 29                                   Samaan, Mr. Elias    male  NaN      2
# 33   Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"  female  NaN      1
# 36                                 Roth, Miss. Sarah A  female  NaN      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
# Get the shape (rows, columns) of the subset of DataFrame where 'Age' is missing
df[df['Age'].isnull()].shape
# Out:
# (86, 12)

# %%
# Select rows 0 to 9 (10 rows) and columns 3 to 5 (3 columns) from the DataFrame using integer-location based indexing
df.iloc[0:10, 3:6]
# Out:
#                                            Name     Sex   Age
# 0                              Kelly, Mr. James    male  34.5
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2                     Myles, Mr. Thomas Francis    male  62.0
# 3                              Wirz, Mr. Albert    male  27.0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# 5                    Svensson, Mr. Johan Cervin    male  14.0
# 6                          Connolly, Miss. Kate  female  30.0
# 7                  Caldwell, Mr. Albert Francis    male  26.0
# 8     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0
# 9                       Davies, Mr. John Samuel    male  21.0

# %%
# Select specific rows with integer positions 1, 3, and 87
# and columns at positions 3, 4, and 5 from the DataFrame
df.iloc[[1, 3, 87], 3:6]
# Out:
#                                 Name     Sex   Age
# 1   Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 3                   Wirz, Mr. Albert    male  27.0
# 87        Badman, Miss. Emily Louisa  female  18.0

# %%
# Use .iloc to select rows with null 'Age' values, and all columns

# Step 1: df['Age'].isnull() creates a boolean mask for null 'Age' rows
# Step 2: df[df['Age'].isnull()].index gets the integer positions (indexes) of these rows
# Step 3: df.iloc[...] selects rows by integer positions, ':' means all columns

df.iloc[df[df['Age'].isnull()].index, :]
# Out:
#      PassengerId  Survived  Pclass  \
# 10           902         0       3
# 22           914         1       1
# 29           921         0       3
# 33           925         1       3
# 36           928         1       3
# ..           ...       ...     ...
# 408         1300         1       3
# 410         1302         1       3
# 413         1305         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 10                                    Ilieff, Mr. Ylio    male  NaN      0
# 22                Flegenheim, Mrs. Alfred (Antoinette)  female  NaN      0
# 29                                   Samaan, Mr. Elias    male  NaN      2
# 33   Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"  female  NaN      1
# 36                                 Roth, Miss. Sarah A  female  NaN      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
# Retrieve the Index object containing all column names of the DataFrame
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# Select rows where 'Survived' is 1 (passengers who survived)
# and show only the 'Survived' and 'Name' columns using label-based indexing
df.loc[df[df['Survived'] == 1].index, ["Survived", 'Name']]
# Out:
#      Survived                                             Name
# 1           1                 Wilkes, Mrs. James (Ellen Needs)
# 4           1     Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 6           1                             Connolly, Miss. Kate
# 8           1        Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 12          1    Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# ..        ...                                              ...
# 409         1                        Peacock, Miss. Treasteall
# 410         1                           Naughton, Miss. Hannah
# 411         1  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 412         1                   Henriksson, Miss. Jenny Lovisa
# 414         1                     Oliva y Ocana, Dona. Fermina
#
# [152 rows x 2 columns]

# %%
# Retrieve all unique values present in the 'Age' column
df['Age'].unique()
# Out:
# array([34.5 , 47.  , 62.  , 27.  , 22.  , 14.  , 30.  , 26.  , 18.  ,
#        21.  ,   nan, 46.  , 23.  , 63.  , 24.  , 35.  , 45.  , 55.  ,
#         9.  , 48.  , 50.  , 22.5 , 41.  , 33.  , 18.5 , 25.  , 39.  ,
#        60.  , 36.  , 20.  , 28.  , 10.  , 17.  , 32.  , 13.  , 31.  ,
#        29.  , 28.5 , 32.5 ,  6.  , 67.  , 49.  ,  2.  , 76.  , 43.  ,
#        16.  ,  1.  , 12.  , 42.  , 53.  , 26.5 , 40.  , 61.  , 60.5 ,
#         7.  , 15.  , 54.  , 64.  , 37.  , 34.  , 11.5 ,  8.  ,  0.33,
#        38.  , 57.  , 40.5 ,  0.92, 19.  , 36.5 ,  0.75,  0.83, 58.  ,
#         0.17, 59.  , 14.5 , 44.  ,  5.  , 51.  ,  3.  , 38.5 ])

# %%
# Count the occurrences of each unique value in the 'Pclass' column
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    218
# 1    107
# 2     93
# Name: count, dtype: int64

# %%
# Create a DataFrame from the value counts of 'Pclass'
pd.DataFrame(df['Pclass'].value_counts())
# Out:
#         count
# Pclass
# 3         218
# 1         107
# 2          93

# %%
# Create a DataFrame from the value counts of 'Pclass' and retrieve its index
pd.DataFrame(df['Pclass'].value_counts()).index
# Out:
# Index([3, 1, 2], dtype='int64', name='Pclass')

# %%
# Calculate the number of missing (null) values in each column of the DataFrame
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
# Display the data types of each column in the DataFrame
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# Drop rows with index labels 1, 2, and 4 from the DataFrame and return a new DataFrame
df.drop([1, 2, 4])
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 0            892         0       3              Kelly, Mr. James    male
# 3            895         0       3              Wirz, Mr. Albert    male
# 5            897         0       3    Svensson, Mr. Johan Cervin    male
# 6            898         1       3          Connolly, Miss. Kate  female
# 7            899         0       2  Caldwell, Mr. Albert Francis    male
# ..           ...       ...     ...                           ...     ...
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
# Remove rows with index labels 412 and 379 from the DataFrame, modifying df directly
df.drop([412, 379], inplace=True)

# Display the updated DataFrame
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
# Remove the column 'Parch' from the DataFrame, modifying df in place
df.drop(['Parch'], axis=1, inplace=True)

# Display the updated DataFrame
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  \
# 0                                Kelly, Mr. James    male  34.5      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                       Myles, Mr. Thomas Francis    male  62.0      0
# 3                                Wirz, Mr. Albert    male  27.0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# ..                                            ...     ...   ...    ...
# ...
