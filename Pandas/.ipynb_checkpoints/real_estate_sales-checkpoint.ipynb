# %%
import pandas as pd
import datetime

df = pd.read_csv('../Datasets/Real_Estate_Sales.csv', low_memory = False)

# %%
# df['Month Name'] = pd.to_datetime(df['Date Recorded']).dt.month_name()

# %%
df['Profit'] = df['Sale Amount'] - df['Assessed Value']

# %%
df['Date Recorded'] = pd.to_datetime(df['Date Recorded'])

# %%
df.insert(3, 'Month Name', df['Date Recorded'].dt.month_name())

# %%
df.insert(9, 'Net Profit', (df['Sale Amount'] * df['Sales Ratio']))

# %%
df.insert(4, 'Date Diff', (pd.to_datetime(datetime.datetime.now().date()) - df['Date Recorded']))

# %%
curr_date = datetime.datetime.now()
round((curr_date - df['Date Recorded']).dt.days / 365)
# Out:
# 0          4.0
# 1          4.0
# 2          4.0
# 3          5.0
# 4          3.0
#           ...
# 1097624    3.0
# 1097625    2.0
# 1097626    3.0
# 1097627    2.0
# 1097628    2.0
# Name: Date Recorded, Length: 1097629, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1097629 entries, 0 to 1097628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Serial Number     1097629 non-null  int64
#  1   List Year         1097629 non-null  int64
#  2   Date Recorded     1097627 non-null  datetime64[ns]
#  3   Month Name        1097627 non-null  object
#  4   Date Diff         1097627 non-null  timedelta64[ns]
#  5   Town              1097629 non-null  object
#  6   Address           1097578 non-null  object
#  7   Assessed Value    1097629 non-null  float64
#  8   Sale Amount       1097629 non-null  float64
#  9   Sales Ratio       1097629 non-null  float64
#  10  Net Profit        1097629 non-null  float64
#  11  Property Type     715183 non-null   object
#  12  Residential Type  699240 non-null   object
#  13  Non Use Code      313451 non-null   object
#  14  Assessor Remarks  171228 non-null   object
# ...

# %%
df.head()
# Out:
#    Serial Number  List Year Date Recorded Month Name Date Diff     Town  \
# 0        2020177       2020    2021-04-14      April 1582 days  Ansonia
# 1        2020225       2020    2021-05-26        May 1540 days  Ansonia
# 2        2020348       2020    2021-09-13  September 1430 days  Ansonia
# 3        2020090       2020    2020-12-14   December 1703 days  Ansonia
# 4         210288       2021    2022-06-20       June 1150 days     Avon
#
#            Address  Assessed Value  Sale Amount  Sales Ratio  Net Profit  \
# 0    323 BEAVER ST        133000.0     248400.0       0.5354   132993.36
# 1   152 JACKSON ST        110500.0     239900.0       0.4606   110497.94
# 2  230 WAKELEE AVE        150500.0     325000.0       0.4630   150475.00
# 3      57 PLATT ST        127400.0     202500.0       0.6291   127392.75
# 4   12 BYRON DRIVE        179990.0     362500.0       0.4965   179981.25
#
#   Property Type Residential Type Non Use Code Assessor Remarks OPM remarks  \
# ...

# %%
# drop all rows where the list year is '2020' and month name is 'January'
year = 2020
month = 'January'

df.drop(index = df.query("`List Year` == @year and `Month Name` == @month").index)
# Out:
#          Serial Number  List Year Date Recorded Month Name Date Diff  \
# 0              2020177       2020    2021-04-14      April 1582 days
# 1              2020225       2020    2021-05-26        May 1540 days
# 2              2020348       2020    2021-09-13  September 1430 days
# 3              2020090       2020    2020-12-14   December 1703 days
# 4               210288       2021    2022-06-20       June 1150 days
# ...                ...        ...           ...        ...       ...
# 1097624        2200073       2022    2022-10-11    October 1037 days
# 1097625         220369       2022    2023-09-29  September  684 days
# 1097626        2200470       2022    2023-01-09    January  947 days
# 1097627          22396       2022    2023-09-26  September  687 days
# 1097628         220890       2022    2023-05-18        May  818 days
#
#                  Town                        Address  Assessed Value  \
# ...

# %%
df.reset_index(drop = True, inplace = True)

# %%
# drop all rows where the list year is '2020' and month name is 'January'
year = 2021
month = 'January'

df.iloc[(df.query("`List Year` == @year and `Month Name` == @month")['Month Name']).index, [3]]
# Out:
#        Month Name
# 222       January
# 266       January
# 329       January
# 340       January
# 397       January
# ...           ...
# 123788    January
# 123789    January
# 123794    January
# 123797    January
# 123801    January
#
# [3986 rows x 1 columns]

# %%
year = 2020
month = 'May'

df.iloc[(df.query("`List Year` == @year and `Month Name` == @month")['Month Name']).index, [3]] = 'January'

# %%
year = 2020
month = 'May'

df.iloc[(df.query("`List Year` == @year and `Month Name` == @month")['Month Name']).index, [3]]
# Out:
# Empty DataFrame
# Columns: [Month Name]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1097629 entries, 0 to 1097628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Serial Number     1097629 non-null  int64
#  1   List Year         1097629 non-null  int64
#  2   Date Recorded     1097627 non-null  datetime64[ns]
#  3   Month Name        1097627 non-null  object
#  4   Date Diff         1097627 non-null  timedelta64[ns]
#  5   Town              1097629 non-null  object
#  6   Address           1097578 non-null  object
#  7   Assessed Value    1097629 non-null  float64
#  8   Sale Amount       1097629 non-null  float64
#  9   Sales Ratio       1097629 non-null  float64
#  10  Net Profit        1097629 non-null  float64
#  11  Property Type     715183 non-null   object
#  12  Residential Type  699240 non-null   object
#  13  Non Use Code      313451 non-null   object
#  14  Assessor Remarks  171228 non-null   object
# ...

# %%
df.groupby(by = ['Month Name'])['Sale Amount'].aggregate(['sum', 'mean']).plot(kind = 'line')
# Out:
# <Axes: xlabel='Month Name'>

# %%
df.groupby(by = ['List Year'])['Sale Amount'].aggregate(['mean']).plot(kind = 'bar')
# Out:
# <Axes: xlabel='List Year'>

# %%
# df.loc[:10000, :].to_xlsx('')
