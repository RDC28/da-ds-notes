# %%
import pandas as pd

df = pd.read_json('../Datasets/NYPD_Arrest_Data__Year_to_Date_.json')
df.head(20)
# Out:
#     ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 0    299458003  01/14/2025    397  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 1    298855625  01/03/2025    847  NY STATE LAWS,UNCLASSIFIED FEL  125.0
# 2    298909765  01/05/2025    729  FORGERY,ETC.,UNCLASSIFIED-FELO  113.0
# 3    298969870  01/06/2025    109        ASSAULT 2,1,UNCLASSIFIED  106.0
# 4    299329792  01/12/2025    101                       ASSAULT 3  344.0
# 5    299750731  01/21/2025    101                       ASSAULT 3  344.0
# 6    299207795  01/10/2025    153                          RAPE 3  104.0
# 7    300151631  01/28/2025    380             ROBBERY,CAR JACKING  105.0
# 8    299400136  01/14/2025    397  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 9    301629843  02/25/2025    109        ASSAULT 2,1,UNCLASSIFIED  106.0
# 10   302400633  03/11/2025    101                       ASSAULT 3  344.0
# 11   304908005  04/17/2025    105               STRANGULATION 1ST  106.0
# ...

# %%
print(df.columns)
print(df.info())
# Out:
# Index(['ARREST_KEY', 'ARREST_DATE', 'PD_CD', 'PD_DESC', 'KY_CD', 'OFNS_DESC',
#        'LAW_CODE', 'LAW_CAT_CD', 'ARREST_BORO', 'ARREST_PRECINCT',
#        'JURISDICTION_CODE', 'AGE_GROUP', 'PERP_SEX', 'PERP_RACE', 'X_COORD_CD',
#        'Y_COORD_CD', 'Latitude', 'Longitude', 'New Georeferenced Column'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143494 entries, 0 to 143493
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ARREST_KEY                143494 non-null  int64
#  1   ARREST_DATE               143494 non-null  object
#  2   PD_CD                     143494 non-null  int64
#  3   PD_DESC                   143494 non-null  object
#  4   KY_CD                     143484 non-null  float64
#  5   OFNS_DESC                 143494 non-null  object
#  6   LAW_CODE                  143494 non-null  object
# ...

# %%
df['ARREST_DATE'] = pd.to_datetime(df['ARREST_DATE'])

# %%
print(df['AGE_GROUP'].value_counts().plot(kind = 'bar'))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
print(df['PERP_SEX'].value_counts().plot(kind = 'bar'))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
df[df['AGE_GROUP'] == '<18']
# Out:
#         ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 4        299329792  2025-01-12    101                       ASSAULT 3  344.0
# 47       301522629  2025-02-22    397  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 57       306159756  2025-05-09    153                          RAPE 3  104.0
# 63       302325256  2025-03-09    397  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 116      298898694  2025-01-04    397  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# ...            ...         ...    ...                             ...    ...
# 143409   307812761  2025-06-09    101                       ASSAULT 3  344.0
# 143417   307722266  2025-06-07    339  LARCENY,PETIT FROM OPEN AREAS,  341.0
# 143447   308770888  2025-06-27    209     BURGLARS TOOLS,UNCLASSIFIED  231.0
# 143463   308756196  2025-06-27    397  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 143493   307979956  2025-06-11    792      CRIMINAL POSSESSION WEAPON  118.0
#
# ...

# %%
df.insert(2, 'ARREST_MONTH', pd.NA)
df['ARREST_MONTH'] = df['ARREST_DATE'].dt.month_name()

# %%
df.groupby(by = ['ARREST_MONTH', 'PERP_SEX']).aggregate('count')
# Out:
#                        ARREST_KEY  ARREST_DATE  PD_CD  PD_DESC  KY_CD  \
# ARREST_MONTH PERP_SEX
# April        F               4598         4598   4598     4598   4597
#              M              20195        20195  20195    20195  20194
# February     F               3910         3910   3910     3910   3910
#              M              18213        18213  18213    18213  18213
# January      F               4145         4145   4145     4145   4145
#              M              20444        20444  20444    20444  20441
# June         F               4313         4313   4313     4313   4313
#              M              18507        18507  18507    18507  18504
# March        F               4486         4486   4486     4486   4486
#              M              20053        20053  20053    20053  20052
# May          F               4623         4623   4623     4623   4622
#              M              20007        20007  20007    20007  20007
#
# ...

# %%
df[df['OFNS_DESC'].isin(['ROBBERY', 'ARSON'])]
# Out:
#         ARREST_KEY ARREST_DATE ARREST_MONTH  PD_CD  \
# 0        299458003  2025-01-14      January    397
# 7        300151631  2025-01-28      January    380
# 8        299400136  2025-01-14      January    397
# 12       300490317  2025-02-03     February    397
# 32       306469070  2025-05-15          May    397
# ...            ...         ...          ...    ...
# 143348   308029237  2025-06-13         June    397
# 143377   307696831  2025-06-07         June    397
# 143401   307907600  2025-06-11         June    397
# 143463   308756196  2025-06-27         June    397
# 143472   308200917  2025-06-17         June    397
#
#                                PD_DESC  KY_CD OFNS_DESC    LAW_CODE  \
# 0       ROBBERY,OPEN AREA UNCLASSIFIED  105.0   ROBBERY  PL 1601502
# 7                  ROBBERY,CAR JACKING  105.0   ROBBERY  PL 1601003
# 8       ROBBERY,OPEN AREA UNCLASSIFIED  105.0   ROBBERY  PL 1601503
# 12      ROBBERY,OPEN AREA UNCLASSIFIED  105.0   ROBBERY  PL 160102A
# ...

# %%
import faker as fk

fake = fk.Faker(["En_In"])

name_list = [fake.name() for i in range(df.shape[0])]

s_name = pd.Series(data = name_list)

# %%
# df.insert(0, 'PERP_NAME', pd.NA)
df['PERP_NAME'] = s_name

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143494 entries, 0 to 143493
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   PERP_NAME                 143494 non-null  object
#  1   ARREST_KEY                143494 non-null  int64
#  2   ARREST_DATE               143494 non-null  datetime64[ns]
#  3   ARREST_MONTH              143494 non-null  object
#  4   PD_CD                     143494 non-null  int64
#  5   PD_DESC                   143494 non-null  object
#  6   KY_CD                     143484 non-null  float64
#  7   OFNS_DESC                 143494 non-null  object
#  8   LAW_CODE                  143494 non-null  object
#  9   LAW_CAT_CD                142807 non-null  object
#  10  ARREST_BORO               143494 non-null  object
#  11  ARREST_PRECINCT           143494 non-null  int64
#  12  JURISDICTION_CODE         143494 non-null  int64
# ...

# %%
df.head()
# Out:
#           PERP_NAME  ARREST_KEY ARREST_DATE ARREST_MONTH  PD_CD  \
# 0       Yug Iyengar   299458003  2025-01-14      January    397
# 1     Arjun Prakash   298855625  2025-01-03      January    847
# 2    Vaishnavi Naik   298909765  2025-01-05      January    729
# 3  Fariq Ramanathan   298969870  2025-01-06      January    109
# 4        Kamya Bera   299329792  2025-01-12      January    101
#
#                           PD_DESC  KY_CD                     OFNS_DESC  \
# 0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0                       ROBBERY
# 1  NY STATE LAWS,UNCLASSIFIED FEL  125.0              OTHER STATE LAWS
# 2  FORGERY,ETC.,UNCLASSIFIED-FELO  113.0                       FORGERY
# 3        ASSAULT 2,1,UNCLASSIFIED  106.0                FELONY ASSAULT
# 4                       ASSAULT 3  344.0  ASSAULT 3 & RELATED OFFENSES
#
#      LAW_CODE LAW_CAT_CD  ... ARREST_PRECINCT  JURISDICTION_CODE  AGE_GROUP  \
# ...
