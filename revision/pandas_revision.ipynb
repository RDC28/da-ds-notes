# %%
import numpy as np
import pandas as pd

# %%
z = np.array([1,2,3,4,np.nan,5,3,6])
z = pd.Series(z)
z
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    NaN
# 5    5.0
# 6    3.0
# 7    6.0
# dtype: float64

# %%
z.mode()
# Out:
# 0    3.0
# dtype: float64

# %%
z.value_counts()
# Out:
# 3.0    2
# 1.0    1
# 2.0    1
# 4.0    1
# 5.0    1
# 6.0    1
# Name: count, dtype: int64

# %%
z > 2
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# 5     True
# 6     True
# 7     True
# dtype: bool

# %%
z[z > 2]
# Out:
# 2    3.0
# 3    4.0
# 5    5.0
# 6    3.0
# 7    6.0
# dtype: float64

# %%
z + 10
# Out:
# 0    11.0
# 1    12.0
# 2    13.0
# 3    14.0
# 4     NaN
# 5    15.0
# 6    13.0
# 7    16.0
# dtype: float64

# %%
(z > 2).sum()
# Out:
# np.int64(5)

# %%
z.isna()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
z.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
z.unique()
# Out:
# array([ 1.,  2.,  3.,  4., nan,  5.,  6.])

# %%
import numpy as np
import pandas as pd
from faker import Faker

fk = Faker(["En_In", "Gu_In"])

# %%
d = {
    "name": [fk.name() for i in range(10)],
    "age": np.random.randint(20, 30, 10)
}

df = pd.DataFrame(data = d)
df
# Out:
#                   name  age
# 0         Chaman Memon   27
# 1           અરુણ શર્મા   24
# 2         Ekta Mahajan   24
# 3       શ્રી અંકિત જૈન   28
# 4   કુમારી ચેતન ગુપ્તા   20
# 5      શ્રી અવની શર્મા   26
# 6            Rohan Som   28
# 7  Chanakya Brahmbhatt   27
# 8       Bhavini Bhasin   22
# 9   શ્રીમતી સંજીવ ગઢવી   24

# %%
names = [fk.name() for i in range(10)]
ages = [np.random.randint(10,30) for i in range(10)]

# %%
s_name = pd.Series(names)
s_age = pd.Series(ages)

df = pd.DataFrame([s_name, s_age])
df
# Out:
#                 0                 1                   2             3  \
# 0  શ્રી કુમાર જૈન  કુમારી સમીર જોષી  શ્રી માન પૂજા જોષી  Azaan Ramesh
# 1              21                21                  23            21
#
#               4           5            6           7            8  \
# 0  Dalbir Borra  Nidra Deol  Warjas Bawa  કૃષ્ણ પટેલ  Barkha Babu
# 1            23          22           28          26           28
#
#                   9
# 0  Sathvik Sengupta
# 1                27

# %%
names = np.array([fk.name() for i in range(10)])
ages =  np.random.randint(20, 30, 10)

# %%
name = pd.DataFrame(names)
age = pd.DataFrame(ages)

# %%
df = pd.concat([name, age], axis = 1)
df.columns = ["Name", "Age"]
df
# Out:
#                    Name  Age
# 0           કૃષ્ણ ચૌધરી   20
# 1        Arunima Shenoy   27
# 2           વિશાલ કુમાર   25
# 3         Kamala Parmer   24
# 4           રાજેશ ચૌધરી   23
# 5         Harini Chadha   27
# 6        Lakshmi Thaman   20
# 7             અનિલ જોષી   27
# 8    શ્રીમતી દીપક ચૌધરી   24
# 9  શ્રી માન દર્શન ચૌધરી   25

# %%
pd.DataFrame(data = {"Name": names,
                     "Age": ages})
# Out:
#                    Name  Age
# 0           કૃષ્ણ ચૌધરી   20
# 1        Arunima Shenoy   27
# 2           વિશાલ કુમાર   25
# 3         Kamala Parmer   24
# 4           રાજેશ ચૌધરી   23
# 5         Harini Chadha   27
# 6        Lakshmi Thaman   20
# 7             અનિલ જોષી   27
# 8    શ્રીમતી દીપક ચૌધરી   24
# 9  શ્રી માન દર્શન ચૌધરી   25

# %%
names = np.array([fk.name() for i in range(10)])
ages =  np.random.randint(20, 30, 10)

data = [[names[i], ages[i]] for i in range(10)]
pd.DataFrame(data = data, columns = ["Name", "Age"])
# Out:
#                   Name  Age
# 0        Krish Sridhar   22
# 1           મહેશ ચૌધરી   27
# 2  શ્રીમતી રમેશ ગુપ્તા   22
# 3         Harsh Grewal   21
# 4          Udarsh Kaul   20
# 5             Kai Shah   22
# 6         વિરાજ ગુપ્તા   25
# 7    Ekaja Subramanian   29
# 8   શ્રીમતી હીરા કુમાર   26
# 9          Dalbir Kant   20

# %%
df = pd.read_clipboard()
df
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df = pd.read_clipboard()
#       2 df
#
# File c:\Users\HP\Desktop\DATA\da-ds-notes\venv\Lib\site-packages\pandas\io\clipboards.py:129, in read_clipboard(sep, dtype_backend, **kwargs)
#     123 elif len(sep) > 1 and kwargs.get("engine") == "c":
#     124     warnings.warn(
#     125         "read_clipboard with regex separator does not work properly with c engine.",
#     126         stacklevel=find_stack_level(),
#     127     )
# --> 129 return read_csv(StringIO(text), sep=sep, dtype_backend=dtype_backend, **kwargs)
#
# ...

# %%
df = pd.read_json("../python/files/json/fakestoreapi.json")
# df = df.drop(columns = ['category', 'image'])

df.drop(columns = ['description', 'rating'], inplace = True)
df
# Out:
#     id                                              title   price  \
# 0    1  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 1    2             Mens Casual Premium Slim Fit T-Shirts    22.30
# 2    3                                 Mens Cotton Jacket   55.99
# 3    4                               Mens Casual Slim Fit   15.99
# 4    5  John Hardy Women's Legends Naga Gold & Silver ...  695.00
# 5    6                       Solid Gold Petite Micropave   168.00
# 6    7                         White Gold Plated Princess    9.99
# 7    8  Pierced Owl Rose Gold Plated Stainless Steel D...   10.99
# 8    9  WD 2TB Elements Portable External Hard Drive -...   64.00
# 9   10  SanDisk SSD PLUS 1TB Internal SSD - SATA III 6...  109.00
# 10  11  Silicon Power 256GB SSD 3D NAND A55 SLC Cache ...  109.00
# 11  12  WD 4TB Gaming Drive Works with Playstation 4 P...  114.00
# 12  13  Acer SB220Q bi 21.5 inches Full HD (1920 x 108...  599.00
# ...

# %%
df.head()
# Out:
#    id                                              title   price  \
# 0   1  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 1   2             Mens Casual Premium Slim Fit T-Shirts    22.30
# 2   3                                 Mens Cotton Jacket   55.99
# 3   4                               Mens Casual Slim Fit   15.99
# 4   5  John Hardy Women's Legends Naga Gold & Silver ...  695.00
#
#          category                                              image
# 0  men's clothing  https://fakestoreapi.com/img/81fPKd-2AYL._AC_S...
# 1  men's clothing  https://fakestoreapi.com/img/71-3HjGNDUL._AC_S...
# 2  men's clothing  https://fakestoreapi.com/img/71li-ujtlUL._AC_U...
# 3  men's clothing  https://fakestoreapi.com/img/71YXzeOuslL._AC_U...
# 4        jewelery  https://fakestoreapi.com/img/71pWzhdJNwL._AC_U...

# %%
df.head(10)
# Out:
#    id                                              title   price  \
# 0   1  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 1   2             Mens Casual Premium Slim Fit T-Shirts    22.30
# 2   3                                 Mens Cotton Jacket   55.99
# 3   4                               Mens Casual Slim Fit   15.99
# 4   5  John Hardy Women's Legends Naga Gold & Silver ...  695.00
# 5   6                       Solid Gold Petite Micropave   168.00
# 6   7                         White Gold Plated Princess    9.99
# 7   8  Pierced Owl Rose Gold Plated Stainless Steel D...   10.99
# 8   9  WD 2TB Elements Portable External Hard Drive -...   64.00
# 9  10  SanDisk SSD PLUS 1TB Internal SSD - SATA III 6...  109.00
#
#          category                                              image
# 0  men's clothing  https://fakestoreapi.com/img/81fPKd-2AYL._AC_S...
# 1  men's clothing  https://fakestoreapi.com/img/71-3HjGNDUL._AC_S...
# ...

# %%
df.tail()
# Out:
#     id                                              title  price  \
# 15  16  Lock and Love Women's Removable Hooded Faux Le...  29.95
# 16  17  Rain Jacket Women Windbreaker Striped Climbing...  39.99
# 17  18        MBJ Women's Solid Short Sleeve Boat Neck V    9.85
# 18  19                 Opna Women's Short Sleeve Moisture   7.95
# 19  20         DANVOUY Womens T Shirt Casual Cotton Short  12.99
#
#             category                                              image
# 15  women's clothing  https://fakestoreapi.com/img/81XH0e8fefL._AC_U...
# 16  women's clothing  https://fakestoreapi.com/img/71HblAHs5xL._AC_U...
# 17  women's clothing  https://fakestoreapi.com/img/71z3kpMAYsL._AC_U...
# 18  women's clothing  https://fakestoreapi.com/img/51eg55uWmdL._AC_U...
# 19  women's clothing  https://fakestoreapi.com/img/61pHAEJ4NML._AC_U...

# %%
df.tail(8)
# Out:
#     id                                              title   price  \
# 12  13  Acer SB220Q bi 21.5 inches Full HD (1920 x 108...  599.00
# 13  14  Samsung 49-Inch CHG90 144Hz Curved Gaming Moni...  999.99
# 14  15  BIYLACLESEN Women's 3-in-1 Snowboard Jacket Wi...   56.99
# 15  16  Lock and Love Women's Removable Hooded Faux Le...   29.95
# 16  17  Rain Jacket Women Windbreaker Striped Climbing...   39.99
# 17  18        MBJ Women's Solid Short Sleeve Boat Neck V     9.85
# 18  19                 Opna Women's Short Sleeve Moisture    7.95
# 19  20         DANVOUY Womens T Shirt Casual Cotton Short   12.99
#
#             category                                              image
# 12       electronics  https://fakestoreapi.com/img/81QpkIctqPL._AC_S...
# 13       electronics  https://fakestoreapi.com/img/81Zt42ioCgL._AC_S...
# 14  women's clothing  https://fakestoreapi.com/img/51Y5NI-I5jL._AC_U...
# 15  women's clothing  https://fakestoreapi.com/img/81XH0e8fefL._AC_U...
# ...

# %%
print(f'columns = {df.columns}')
print(f'shape = {df.shape}')
print(f'index = {df.index}')
print(f'unique = {df["price"].unique()}')
print(f'value_counts = {df["category"].value_counts()}')
print(f'info = {df.info()}')
print(f'describe = {df.describe()}')
# Out:
# columns = Index(['id', 'title', 'price', 'category', 'image'], dtype='object')
# shape = (20, 5)
# index = RangeIndex(start=0, stop=20, step=1)
# unique = [109.95  22.3   55.99  15.99 695.   168.     9.99  10.99  64.   109.
#  114.   599.   999.99  56.99  29.95  39.99   9.85   7.95  12.99]
# value_counts = category
# women's clothing    6
# electronics         6
# jewelery            4
# men's clothing      4
# Name: count, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        20 non-null     int64
#  1   title     20 non-null     object
#  2   price     20 non-null     float64
#  3   category  20 non-null     object
#  4   image     20 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 932.0+ bytes
# info = None
# describe =              id       price
# count  20.00000   20.000000
# ...

# %%
import numpy as np
import pandas as pd
from datetime import datetime
from faker import Faker

fk = Faker(["En_In", "Gu_In"])

# %%
data = {
    "first_name" : [],
    "last_name"  : [],
    "email" : [],
    "city" : [],
    "ordered_amount" : [],
    "joined_date" : [],
}

for i in range(100000):
    data["first_name"].append(fk.first_name())
    data["last_name"].append(fk.last_name())
    data["email"].append(fk.email())
    data["city"].append(fk.city())
    data["ordered_amount"].append(np.random.randint(0,100))
    data["joined_date"].append(fk.date_between(end_date = datetime.now()))

# %%
df = pd.DataFrame(data = data)
df.head()
# Out:
#   first_name last_name                       email         city  \
# 0         યશ       જૈન    eshanasarkar@example.com  New બ્રિજેશ
# 1     Bhavna    ગુપ્તા    doctorxavier@example.org     New અશોક
# 2       સમીર    Bhagat  priiticaudhrii@example.net       Aizawl
# 3      અંકિત      Kaur        suhani29@example.com   સુનીલhaven
# 4      David     Magar         tnvii64@example.net    શર્માfort
#
#    ordered_amount joined_date
# 0              93  2003-12-25
# 1              89  2020-07-01
# 2              54  2023-10-18
# 3              88  2000-02-04
# 4              62  2012-02-07

# %%
df['ordered_amount'] = df['ordered_amount'].astype('float64')

# %%
df['joined_date'] = pd.to_datetime(df['joined_date'])

# %%
df['Month_name'] = df['joined_date'].dt.month_name()

# %%
emails = []
for email in df['email']:
    domain = email[-11:]
    
    if domain == 'example.com':
        emails.append(email.replace('example.com', 'google.com'))
    elif domain == 'example.net':
        emails.append(email.replace('example.net', 'mailgun.net'))
    elif domain == 'example.org':
        emails.append(email.replace('example.org', 'mailbox.org'))
    else:
        emails.append(email)
        
emails
# Out:
# ['eshanasarkar@google.com',
#  'doctorxavier@mailbox.org',
#  'priiticaudhrii@mailgun.net',
#  'suhani29@google.com',
#  'tnvii64@mailgun.net',
#  'jossiidiipk@mailgun.net',
#  'kcaudhrii@mailgun.net',
#  'jyashrmaa@mailbox.org',
#  'joshua97@mailgun.net',
#  'praaciijossii@google.com',
#  'achana@mailgun.net',
#  'abhissekcaudhrii@mailgun.net',
#  'vsnt47@mailgun.net',
#  'nitin65@mailgun.net',
#  'caudhriihiiraa@mailbox.org',
#  'oshan@mailgun.net',
#  'siddhaarthgddhvii@mailbox.org',
#  'bjain@mailgun.net',
#  'tejlshrmaa@mailbox.org',
#  'raajendrcaudhrii@mailgun.net',
#  'sonl89@mailbox.org',
#  'muniisha@mailgun.net',
#  'yashawini16@mailbox.org',
#  'praacii21@mailgun.net',
#  'guptaadrshn@mailbox.org',
#  'bhavyasubramanian@mailgun.net',
#  'tkumaar@google.com',
#  'jayaramannoah@google.com',
#  'pttelkunaal@mailgun.net',
#  'palnaksh@mailbox.org',
#  'pcaudhrii@mailgun.net',
#  'dakshadara@mailbox.org',
#  'hsetty@mailgun.net',
#  'gddhviiyash@mailbox.org',
# ...

# %%
df['email'] = pd.Series(emails)
# Out:
#   first_name last_name                       email         city  \
# 0         યશ       જૈન     eshanasarkar@google.com  New બ્રિજેશ
# 1     Bhavna    ગુપ્તા    doctorxavier@mailbox.org     New અશોક
# 2       સમીર    Bhagat  priiticaudhrii@mailgun.net       Aizawl
# 3      અંકિત      Kaur         suhani29@google.com   સુનીલhaven
# 4      David     Magar         tnvii64@mailgun.net    શર્માfort
#
#    ordered_amount joined_date Month_name
# 0            93.0  2003-12-25   December
# 1            89.0  2020-07-01       July
# 2            54.0  2023-10-18    October
# 3            88.0  2000-02-04   February
# 4            62.0  2012-02-07   February

# %%
is_primes = ["yes" if value > 50 else "no" for value in df['ordered_amount']]
is_primes
# Out:
# ['yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'no',
#  'no',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'no',
# ...

# %%
df['is_prime'] = pd.Series(is_primes)

# %%
df.head(10)
# Out:
#    first_name last_name                       email           city  \
# 0          યશ       જૈન     eshanasarkar@google.com    New બ્રિજેશ
# 1      Bhavna    ગુપ્તા    doctorxavier@mailbox.org       New અશોક
# 2        સમીર    Bhagat  priiticaudhrii@mailgun.net         Aizawl
# 3       અંકિત      Kaur         suhani29@google.com     સુનીલhaven
# 4       David     Magar         tnvii64@mailgun.net      શર્માfort
# 5      નિશાંત      જોષી     jossiidiipk@mailgun.net         Karnal
# 6  Bahadurjit     Bobal       kcaudhrii@mailgun.net         Indore
# 7       દિનેશ     શર્મા       jyashrmaa@mailbox.org           Agra
# 8     Tanveer     Reddy        joshua97@mailgun.net  Muzaffarnagar
# 9       Daksh      જોષી    praaciijossii@google.com        Gurgaon
#
#    ordered_amount joined_date Month_name is_prime
# 0            93.0  2003-12-25   December      yes
# 1            89.0  2020-07-01       July      yes
# 2            54.0  2023-10-18    October      yes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   first_name      100000 non-null  object
#  1   last_name       100000 non-null  object
#  2   email           100000 non-null  object
#  3   city            100000 non-null  object
#  4   ordered_amount  100000 non-null  float64
#  5   joined_date     100000 non-null  datetime64[ns]
#  6   Month_name      100000 non-null  object
#  7   is_prime        100000 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 6.1+ MB
